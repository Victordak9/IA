# %%
import cv2 

# img = cv2.imread('/home/likcos/DataSets/sportimages/sportimages/basket/basket2_0001.jpg')
# print(img.shape[0], img.shape[1], img.shape[2], len(img.shape))

# %% [markdown]
# # Convolutional Neural Networks

# %% [markdown]
# # Importar Librerías

# %%
import numpy as np
import os
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
import keras
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential,Model
from tensorflow.keras.layers import Input
from keras.layers import Dense, Dropout, Flatten
#from keras.layers import Conv2D, MaxPooling2D
#from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    BatchNormalization, SeparableConv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense, Conv2D
)
from keras.layers import LeakyReLU

# %% [markdown]
# # Cargar set de Imágenes

# %%
dirname = os.path.join(os.getcwd(),'./datasets')
imgpath = dirname + os.sep 

images = []
directories = []
dircount = []
prevRoot=''
cant=0

print("leyendo imagenes de ",imgpath)

for root, dirnames, filenames in os.walk(imgpath):
    for filename in filenames:
        if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
            cant=cant+1
            filepath = os.path.join(root, filename)
            image = plt.imread(filepath)
            if(len(image.shape)==3):
                
                images.append(image)
            b = "Leyendo..." + str(cant)
            print (b, end="\r")
            if prevRoot !=root:
                print(root, cant)
                prevRoot=root
                directories.append(root)
                dircount.append(cant)
                cant=0
dircount.append(cant)

dircount = dircount[1:]
dircount[0]=dircount[0]+1
print('Directorios leidos:',len(directories))
print("Imagenes en cada directorio", dircount)
print('suma Total de imagenes en subdirs:',sum(dircount))
# Out:
# leyendo imagenes de  d:\DocumentosHDD\9no_Semestre\Inteligencia Artificial\IA\./datasets\
# d:\DocumentosHDD\9no_Semestre\Inteligencia Artificial\IA\./datasets\aves 1
# Leyendo...403
# d:\DocumentosHDD\9no_Semestre\Inteligencia Artificial\IA\./datasets\cempsuchs 3663
# d:\DocumentosHDD\9no_Semestre\Inteligencia Artificial\IA\./datasets\lavanda 3330
# d:\DocumentosHDD\9no_Semestre\Inteligencia Artificial\IA\./datasets\pass 1628
# d:\DocumentosHDD\9no_Semestre\Inteligencia Artificial\IA\./datasets\tulips 1480
# Directorios leidos: 5
# Imagenes en cada directorio [3664, 3330, 1628, 1480, 2145]
# suma Total de imagenes en subdirs: 12247

# %% [markdown]
# # Creamos las etiquetas

# %%
labels=[]
indice=0
for cantidad in dircount:
    for i in range(cantidad):
        labels.append(indice)
    indice=indice+1
print("Cantidad etiquetas creadas: ",len(labels))
# Out:
# Cantidad etiquetas creadas:  12247

# %%
flores=[]
indice=0
for directorio in directories:
    name = directorio.split(os.sep)
    print(indice , name[len(name)-1])
    flores.append(name[len(name)-1])
    indice=indice+1
# Out:
# 0 aves
# 1 cempsuchs
# 2 lavanda
# 3 pass
# 4 tulips

# %%
y = np.array(labels)
X = np.array(images, dtype=np.uint8) #convierto de lista a numpy



# Find the unique numbers from the train labels
classes = np.unique(y)
nClasses = len(classes)
print('Total number of outputs : ', nClasses)
print('Output classes : ', classes)
# Out:
# Total number of outputs :  5
# Output classes :  [0 1 2 3 4]

# %% [markdown]
# # Creamos Sets de Entrenamiento y Test

# %%
train_X,test_X,train_Y,test_Y = train_test_split(X,y,test_size=0.2)
print('Training data shape : ', train_X.shape, train_Y.shape)
print('Testing data shape : ', test_X.shape, test_Y.shape)
# Out:
# Training data shape :  (9797, 32, 32, 3) (9797,)
# Testing data shape :  (2450, 32, 32, 3) (2450,)

# %%
plt.figure(figsize=[5,5])

# Display the first image in training data
plt.subplot(121)
plt.imshow(train_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(train_Y[0]))

# Display the first image in testing data
plt.subplot(122)
plt.imshow(test_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(test_Y[0]))
# Out:
# Text(0.5, 1.0, 'Ground Truth : 1')

# %% [markdown]
# # Preprocesamos las imagenes

# %%
train_X = train_X.astype('float32')
test_X = test_X.astype('float32')
train_X = train_X/255.
test_X = test_X/255.
plt.imshow(test_X[0,:,:])

# %% [markdown]
# ## Hacemos el One-hot Encoding para la red

# %%
# Change the labels from categorical to one-hot encoding
train_Y_one_hot = to_categorical(train_Y)
test_Y_one_hot = to_categorical(test_Y)

# Display the change for category label using one-hot encoding
print('Original label:', train_Y[0])
print('After conversion to one-hot:', train_Y_one_hot[0])
# Out:
# Original label: 2
# After conversion to one-hot: [0. 0. 1. 0. 0.]

# %% [markdown]
# # Creamos el Set de Entrenamiento y Validación

# %%
#Mezclar todo y crear los grupos de entrenamiento y testing
train_X,valid_X,train_label,valid_label = train_test_split(train_X, train_Y_one_hot, test_size=0.2, random_state=13)

# %%
print(train_X.shape,valid_X.shape,train_label.shape,valid_label.shape)
# Out:
# (7837, 32, 32, 3) (1960, 32, 32, 3) (7837, 5) (1960, 5)

# %% [markdown]
# # Creamos el modelo de CNN

# %%
#declaramos variables con los parámetros de configuración de la red
INIT_LR = 1e-3 # Valor inicial de learning rate. El valor 1e-3 corresponde con 0.001
epochs = 200 # Cantidad de iteraciones completas al conjunto de imagenes de entrenamiento
batch_size = 32 # cantidad de imágenes que se toman a la vez en memoria

# %%
flower_model = Sequential()
flower_model.add(Conv2D(16, kernel_size=(5, 5),activation='linear',padding='same',input_shape=(32,32,3)))
flower_model.add(LeakyReLU(alpha=0.1))
flower_model.add(MaxPooling2D((2, 2),padding='same'))
flower_model.add(Dropout(0.5))

flower_model.add(Flatten())
flower_model.add(Dense(32, activation='linear'))
flower_model.add(LeakyReLU(alpha=0.1))
flower_model.add(Dropout(0.5))
flower_model.add(Dense(nClasses, activation='softmax'))

# %%
flower_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 32, 32, 16)        1216
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 32, 32, 16)        0
#
#  max_pooling2d_5 (MaxPoolin  (None, 16, 16, 16)        0
#  g2D)
#
#  dropout_10 (Dropout)        (None, 16, 16, 16)        0
#
#  flatten_5 (Flatten)         (None, 4096)              0
#
#  dense_10 (Dense)            (None, 32)                131104
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 32)                0
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_11 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 132485 (517.52 KB)
# Trainable params: 132485 (517.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
flower_model.compile(loss=keras.losses.categorical_crossentropy, optimizer=tf.keras.optimizers.legacy.SGD(learning_rate=INIT_LR, decay=INIT_LR / 100),metrics=['accuracy'])

# %% [markdown]
# # Entrenamos el modelo: Aprende a clasificar imágenes

# %%
# este paso puede tomar varios minutos, dependiendo de tu ordenador, cpu y memoria ram libre
flower_train = flower_model.fit(train_X, train_label, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_label))
# Out:
# Epoch 1/200
# 245/245 [==============================] - 3s 9ms/step - loss: 1.6003 - accuracy: 0.2849 - val_loss: 1.4652 - val_accuracy: 0.5071
# Epoch 2/200
# 245/245 [==============================] - 2s 8ms/step - loss: 1.4136 - accuracy: 0.4207 - val_loss: 1.2507 - val_accuracy: 0.5388
# Epoch 3/200
# 245/245 [==============================] - 2s 7ms/step - loss: 1.2737 - accuracy: 0.4771 - val_loss: 1.1291 - val_accuracy: 0.5464
# Epoch 4/200
# 245/245 [==============================] - 2s 10ms/step - loss: 1.1992 - accuracy: 0.5084 - val_loss: 1.0721 - val_accuracy: 0.6199
# Epoch 5/200
# 245/245 [==============================] - 2s 7ms/step - loss: 1.1425 - accuracy: 0.5315 - val_loss: 1.0149 - val_accuracy: 0.6372
# Epoch 6/200
# 245/245 [==============================] - 2s 8ms/step - loss: 1.1065 - accuracy: 0.5479 - val_loss: 0.9722 - val_accuracy: 0.6663
# Epoch 7/200
# 245/245 [==============================] - 2s 8ms/step - loss: 1.0735 - accuracy: 0.5748 - val_loss: 0.9348 - val_accuracy: 0.6934
# Epoch 8/200
# 245/245 [==============================] - 2s 8ms/step - loss: 1.0342 - accuracy: 0.5916 - val_loss: 0.9018 - val_accuracy: 0.7148
# Epoch 9/200
# 245/245 [==============================] - 2s 9ms/step - loss: 1.0213 - accuracy: 0.6062 - val_loss: 0.8836 - val_accuracy: 0.7036
# Epoch 10/200
# 245/245 [==============================] - 2s 8ms/step - loss: 0.9820 - accuracy: 0.6235 - val_loss: 0.8538 - val_accuracy: 0.7179
# Epoch 11/200
# 245/245 [==============================] - 2s 7ms/step - loss: 0.9692 - accuracy: 0.6317 - val_loss: 0.8367 - val_accuracy: 0.7337
# Epoch 12/200
# 245/245 [==============================] - 2s 7ms/step - loss: 0.9390 - accuracy: 0.6485 - val_loss: 0.8150 - val_accuracy: 0.7316
# Epoch 13/200
# 245/245 [==============================] - 2s 7ms/step - loss: 0.9236 - accuracy: 0.6612 - val_loss: 0.7854 - val_accuracy: 0.7418
# Epoch 14/200
# 245/245 [==============================] - 2s 7ms/step - loss: 0.8937 - accuracy: 0.6671 - val_loss: 0.7633 - val_accuracy: 0.7561
# Epoch 15/200
# 245/245 [==============================] - 2s 7ms/step - loss: 0.8767 - accuracy: 0.6825 - val_loss: 0.7463 - val_accuracy: 0.7561
# Epoch 16/200
# 245/245 [==============================] - 2s 7ms/step - loss: 0.8552 - accuracy: 0.6899 - val_loss: 0.7338 - val_accuracy: 0.7724
# Epoch 17/200
# 245/245 [==============================] - 2s 7ms/step - loss: 0.8445 - accuracy: 0.6962 - val_loss: 0.7183 - val_accuracy: 0.7872
# Epoch 18/200
# 245/245 [==============================] - 2s 6ms/step - loss: 0.8276 - accuracy: 0.7065 - val_loss: 0.7048 - val_accuracy: 0.7770
# Epoch 19/200
# 245/245 [==============================] - 2s 7ms/step - loss: 0.8134 - accuracy: 0.7120 - val_loss: 0.6930 - val_accuracy: 0.7944
# Epoch 20/200
# 245/245 [==============================] - 2s 7ms/step - loss: 0.8016 - accuracy: 0.7213 - val_loss: 0.6787 - val_accuracy: 0.7985
# Epoch 21/200
# 245/245 [==============================] - 2s 7ms/step - loss: 0.7799 - accuracy: 0.7278 - val_loss: 0.6606 - val_accuracy: 0.7883
# Epoch 22/200
# 245/245 [==============================] - 2s 7ms/step - loss: 0
200
# 245/245 [==============================] - 2s 7ms/step - loss: 0.2775 - accuracy: 0.9061 - val_loss: 0.1920 - val_accuracy: 0.9321
# Epoch 196/200
# 245/245 [==============================] - 2s 7ms/step - loss: 0.2836 - accuracy: 0.9037 - val_loss: 0.1929 - val_accuracy: 0.9321
# Epoch 197/200
# 245/245 [==============================] - 2s 7ms/step - loss: 0.2769 - accuracy: 0.9070 - val_loss: 0.1923 - val_accuracy: 0.9332
# Epoch 198/200
# 245/245 [==============================] - 2s 6ms/step - loss: 0.2756 - accuracy: 0.9069 - val_loss: 0.1917 - val_accuracy: 0.9337
# Epoch 199/200
# 245/245 [==============================] - 2s 7ms/step - loss: 0.2826 - accuracy: 0.9029 - val_loss: 0.1915 - val_accuracy: 0.9332
# Epoch 200/200
# 245/245 [==============================] - 2s 7ms/step - loss: 0.2838 - accuracy: 0.9016 - val_loss: 0.1904 - val_accuracy: 0.9337

# %%
# guardamos la red, para reutilizarla en el futuro, sin tener que volver a entrenar
flower_model.save("./flores.h5py")
# Out:
# INFO:tensorflow:Assets written to: ./flores.h5py\assets
# INFO:tensorflow:Assets written to: ./flores.h5py\assets

# %% [markdown]
# # Evaluamos la red

# %%
test_eval = flower_model.evaluate(test_X, test_Y_one_hot, verbose=1)
# Out:
# 77/77 [==============================] - 0s 3ms/step - loss: 0.2011 - accuracy: 0.9355

# %%
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# Test loss: 0.20112758874893188
# Test accuracy: 0.9355102181434631

# %%
flower_model.history

# %%
accuracy = flower_train.history['accuracy']
val_accuracy = flower_train.history['val_accuracy']
loss = flower_train.history['loss']
val_loss = flower_train.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
predicted_classes2 = flower_model.predict(test_X)
# Out:
# 77/77 [==============================] - 0s 2ms/step

# %%
predicted_classes=[]
for predicted_flower in predicted_classes2:
    predicted_classes.append(predicted_flower.tolist().index(max(predicted_flower)))
predicted_classes=np.array(predicted_classes)

# %%
predicted_classes.shape, test_Y.shape
# Out:
# ((2450,), (2450,))

# %% [markdown]
# # Aprendamos de los errores: Qué mejorar

# %%
correct = np.where(predicted_classes==test_Y)[0]
print("Found %d correct labels" % len(correct))
for i, correct in enumerate(correct[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[correct].reshape(32,32,3), cmap='gray', interpolation='none')
    plt.title("{}, {}".format(flores[predicted_classes[correct]],
                                                    flores[test_Y[correct]]))

    plt.tight_layout()
# Out:
# Found 2292 correct labels

# %%
incorrect = np.where(predicted_classes!=test_Y)[0]
print("Found %d incorrect labels" % len(incorrect))
for i, incorrect in enumerate(incorrect[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[incorrect].reshape(32,32,3), cmap='gray', interpolation='none')
    plt.title("{}, {}".format(flores[predicted_classes[incorrect]],
                                                    flores[test_Y[incorrect]]))
    plt.tight_layout()
# Out:
# Found 158 incorrect labels

# %%
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(test_Y, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.92      0.96      0.94       716
#      Class 1       0.96      0.95      0.95       691
#      Class 2       0.93      0.92      0.92       319
#      Class 3       0.92      0.94      0.93       308
#      Class 4       0.94      0.88      0.91       416
#
#     accuracy                           0.94      2450
#    macro avg       0.93      0.93      0.93      2450
# weighted avg       0.94      0.94      0.94      2450
